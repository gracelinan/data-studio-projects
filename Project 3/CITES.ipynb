# %%
import pandas as pd

# %%
df = pd.read_csv("comptab_2019-07-23 10_37_comma_separated.csv")

# %%
df.shape
df.head(10)
# Out:
#    Year App.                       Taxon     Class          Order  \
# 0  2014    I        Haliaeetus albicilla      Aves  Falconiformes
# 1  2014    I            Agave parviflora       NaN       Liliales
# 2  2014    I             Ailurus fulgens  Mammalia      Carnivora
# 3  2014    I  Balaenoptera acutorostrata  Mammalia        Cetacea
# 4  2014    I        Balaenopteridae spp.  Mammalia        Cetacea
# 5  2014    I                   Bos mutus  Mammalia   Artiodactyla
# 6  2014    I                Bovidae spp.  Mammalia   Artiodactyla
# 7  2014    I                Bovidae spp.  Mammalia   Artiodactyla
# 8  2014    I                 Oryx dammah  Mammalia   Artiodactyla
# 9  2014    I                 Oryx dammah  Mammalia   Artiodactyla
#
#             Family         Genus Importer Exporter Origin  \
# 0     Accipitridae    Haliaeetus       CN       KR     XX
# 1        Agavaceae         Agave       CN       US    NaN
# 2        Ailuridae       Ailurus       CN       KR     XX
# ...

# %%
df.dtypes
# Out:
# Year                            int64
# App.                           object
# Taxon                          object
# Class                          object
# Order                          object
# Family                         object
# Genus                          object
# Importer                       object
# Exporter                       object
# Origin                         object
# Importer reported quantity    float64
# Exporter reported quantity    float64
# Term                           object
# Unit                           object
# Purpose                        object
# Source                         object
# dtype: object

# %%
df.Taxon.value_counts().head()
# Out:
# Crocodylus niloticus          1291
# Crocodylus porosus             993
# Alligator mississippiensis     967
# Python reticulatus             892
# Loxodonta africana             670
# Name: Taxon, dtype: int64

# %%
df[df.Taxon == 'Loxodonta africana']
# Out:
#        Year App.               Taxon     Class        Order        Family  \
# 326    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 327    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 328    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 329    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 330    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 331    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 332    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 333    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 334    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 335    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 336    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# 337    2014    I  Loxodonta africana  Mammalia  Proboscidea  Elephantidae
# ...

# %%
df.Importer.value_counts().head()
# Out:
# CN    11373
# HK    10869
# MO      995
# Name: Importer, dtype: int64

# %%
df.Exporter.value_counts().head()
# Out:
# IT    2486
# FR    1771
# NL    1452
# ID    1442
# US    1168
# Name: Exporter, dtype: int64

# %%
df2007 = pd.read_csv("2007_China.csv")

# %%
df2007.shape
# Out:
# (3102, 16)

# %%
df[df.Exporter == 'US'].Taxon.value_counts().head()
# Out:
# Panax quinquefolius           101
# Alligator mississippiensis    100
# Macaca fascicularis            63
# Crocodylus niloticus           29
# Loxodonta africana             26
# Name: Taxon, dtype: int64

# %%
df2 = pd.read_csv("2014_countries.csv")

# %%
df2.Importer.value_counts()
# Out:
# US    14895
# JP     5856
# CN     2910
# GB     1843
# Name: Importer, dtype: int64

# %%
df2[df2.Importer == 'GB'].Taxon.value_counts().head()
# Out:
# Loxodonta africana            58
# Crocodylus niloticus          51
# Macaca fascicularis           34
# Alligator mississippiensis    32
# Falco rusticolus              31
# Name: Taxon, dtype: int64

# %%
df3 = pd.read_csv("2017_countries.csv")

# %%
df3.Importer.value_counts()
# Out:
# US    12710
# JP     6021
# HK     3016
# CN     2866
# GB     1609
# Name: Importer, dtype: int64

# %%
df3[(df3.Importer == 'US') & (df3.Taxon == 'Crocodylus niloticus')]
# Out:
#       Year App.                 Taxon     Class       Order        Family  \
# 445   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 446   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 447   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 448   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 449   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 450   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 451   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 452   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 453   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 454   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 455   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 456   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# ...

# %%
df3[(df3.Importer == 'CN') & (df3.Taxon == 'Crocodylus niloticus')]
# Out:
#       Year App.                 Taxon     Class       Order        Family  \
# 436   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 437   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 438   2017    I  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8312  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8313  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8314  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8315  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8316  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8317  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8318  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8319  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# 8320  2017   II  Crocodylus niloticus  Reptilia  Crocodylia  Crocodylidae
# ...
