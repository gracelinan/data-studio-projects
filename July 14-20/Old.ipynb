# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
ls
# Out:
# NYPD_Complaint_Data_Historic.csv
# NYPD_Complaint_Historic_DataDictionary.xlsx
# Police cases.ipynb

# %%
df = pd.read_csv("NYPD_Complaint_Data_Historic.csv")

def lookup(s):
   dates = {date:pd.to_datetime(date, errors='coerce') for date in s.unique()}
   return s.map(dates)
# Out:
# /Users/grace/.pyenv/versions/3.7.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df['CMPLNT_FR_DT_datetime'] = lookup(df['CMPLNT_FR_DT'])
df['CMPLNT_year'] = df['CMPLNT_FR_DT_datetime'].apply(lambda x: x.year)

# %%
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   554829619   05/19/2014     08:30:00   05/20/2014     11:30:00
# 1   219274724   05/19/2014     08:15:00   05/19/2014     14:00:00
# 2   609429777   05/19/2014     08:00:00   05/19/2014     23:50:00
# 3   981103394   05/19/2014     08:00:00   05/19/2014     08:10:00
# 4   768067271   05/19/2014     06:30:00   05/19/2014     07:00:00
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                OFNS_DESC  PD_CD  ...  \
# 0        122.0  05/20/2014    578            HARRASSMENT 2  637.0  ...
# 1         67.0  05/20/2014    341            PETIT LARCENY  338.0  ...
# 2        114.0  05/20/2014    107                 BURGLARY  221.0  ...
# 3        112.0  05/20/2014    126  MISCELLANEOUS PENAL LAW  198.0  ...
# 4        114.0  05/20/2014    578            HARRASSMENT 2  637.0  ...
#
#     Latitude  Longitude                        Lat_Lon  \
# 0  40.560905 -74.111266  (40.560905178, -74.111266419)
# ...

# %%
df.shape
# Out:
# (6500870, 37)

# %%
df.dtypes
# Out:
# CMPLNT_NUM                        int64
# CMPLNT_FR_DT                     object
# CMPLNT_FR_TM                     object
# CMPLNT_TO_DT                     object
# CMPLNT_TO_TM                     object
# ADDR_PCT_CD                     float64
# RPT_DT                           object
# KY_CD                             int64
# OFNS_DESC                        object
# PD_CD                           float64
# PD_DESC                          object
# CRM_ATPT_CPTD_CD                 object
# LAW_CAT_CD                       object
# BORO_NM                          object
# LOC_OF_OCCUR_DESC                object
# PREM_TYP_DESC                    object
# JURIS_DESC                       object
# JURISDICTION_CODE               float64
# PARKS_NM                         object
# HADEVELOPT                       object
# HOUSING_PSA                      object
# X_COORD_CD                      float64
# Y_COORD_CD                      float64
# ...

# %%
df.PARKS_NM.value_counts()
# Out:
# CENTRAL PARK                                           1252
# FLUSHING MEADOWS CORONA PARK                           1016
# CONEY ISLAND BEACH & BOARDWALK                          805
# RIVERSIDE PARK                                          495
# PROSPECT PARK                                           385
# WASHINGTON SQUARE PARK                                  367
# UNION SQUARE PARK                                       359
# RANDALL'S ISLAND PARK                                   330
# MARCUS GARVEY PARK                                      318
# MACOMBS DAM PARK                                        285
# CLAREMONT PARK                                          273
# ST. MARY'S PARK BRONX                                   257
# CROTONA PARK                                            249
# SARA D. ROOSEVELT PARK                                  230
# VAN CORTLANDT PARK                                      230
# ROCKAWAY BEACH AND BOARDWALK                            228
# ...

# %%
df.BORO_NM.value_counts()
# Out:
# BROOKLYN         1935028
# MANHATTAN        1557920
# BRONX            1408361
# QUEENS           1282057
# STATEN ISLAND     306986
# Name: BORO_NM, dtype: int64

# %%
df.HADEVELOPT.value_counts()
# Out:
# CASTLE HILL                                    7081
# VAN DYKE I                                     5733
# MARCY                                          5304
# BUTLER                                         4946
# LINCOLN                                        4858
# GRANT                                          4754
# LINDEN                                         4729
# DOUGLASS                                       4613
# PINK                                           4593
# FARRAGUT                                       4465
# BRONXDALE                                      4436
# BROWNSVILLE                                    4427
# SOUNDVIEW                                      4338
# BARUCH                                         4268
# THROGGS NECK                                   4143
# BUSHWICK                                       3947
# INGERSOLL                                      3920
# POMONOK                                        3904
# ...

# %%
df.STATION_NAME.value_counts()
# Out:
# 125 STREET                        7427
# 14 STREET                         4113
# 34 ST.-PENN STATION               3445
# 42 ST.-PORT AUTHORITY BUS TERM    3381
# 116 STREET                        3132
# 42 ST.-GRAND CENTRAL              2864
# 42 ST.-TIMES SQUARE               2803
# CANAL STREET                      2211
# 59 ST.-COLUMBUS CIRCLE            1964
# UTICA AVE.-CROWN HEIGHTS          1820
# 86 STREET                         1643
# 59 STREET                         1542
# 3 AVENUE-149 STREET               1537
# JAY STREET-BOROUGH HALL           1406
# 96 STREET                         1378
# PARSONS/ARCHER-JAMAICA CENTER     1347
# NOSTRAND AVENUE                   1343
# FORDHAM ROAD                      1332
# 145 STREET                        1326
# 23 STREET                         1281
# 161 ST.-YANKEE STADIUM            1255
# 34 ST.-HERALD SQ.                 1231
# W. 4 STREET                       1191
# UNION SQUARE                      1159
# ...

# %%
df = df.dropna(subset=['STATION_NAME'])

# %%
df[df.STATION_NAME.str.contains('125')].Latitude.value_counts()
# Out:
# 40.804384    4094
# 40.810773    1302
# 40.807781    1079
# 40.815696     222
# 40.804384     212
# 40.807781     144
# 40.810773     142
# 40.800694      85
# 40.814850      46
# 40.815696      18
# 40.800694      15
# 40.808750       9
# 40.812016       8
# 40.798633       4
# 40.804695       4
# 40.811377       3
# 40.824040       2
# 40.812016       2
# 40.804046       2
# 40.808750       2
# 40.802032       1
# 40.800930       1
# 40.814850       1
# 40.804112       1
# 40.799841       1
# 40.815128       1
# 40.804258       1
# 40.803706       1
# 40.815372       1
# 40.767869       1
# 40.808456       1
# 40.805846       1
# 40.817017       1
# 40.818811       1
# 40.810950       1
# 40.808374       1
# 40.798633       1
# 40.807877       1
# 40.807670       1
# 40.678681       1
# 40.817125       1
# 40.794817       1
# 40.805066       1
# 40.810551       1
# 40.811451       1
# Name: Latitude, dtype: int64

# %%
df[df.STATION_NAME.str.contains('125')].Longitude.value_counts()
# Out:
# -73.937422    4094
# -73.952592    1302
# -73.945485    1079
# -73.958293     222
# -73.937422     212
# -73.945485     144
# -73.952592     142
# -73.941109      85
# -73.956682      46
# -73.958293      18
# -73.941109      15
# -73.952586       9
# -73.951507       8
# -73.938158       4
# -73.941620       4
# -73.954011       3
# -73.951507       2
# -73.952586       2
# -73.936620       2
# -73.944760       2
# -73.936801       1
# -73.948010       1
# -73.937914       1
# -73.956682       1
# -73.824272       1
# -73.952103       1
# -73.946902       1
# -73.944408       1
# -73.958701       1
# -73.958025       1
# -73.941098       1
# -73.949683       1
# -73.943155       1
# -73.952765       1
# -73.964077       1
# -73.945402       1
# -73.946886       1
# -73.943174       1
# -73.959495       1
# -73.956025       1
# -73.942410       1
# -73.939036       1
# -73.941620       1
# -73.944997       1
# -73.937100       1
# Name: Longitude, dtype: int64

# %%
df.TRANSIT_DISTRICT.value_counts()
# Out:
# 4.0     25247
# 2.0     17356
# 3.0     14098
# 1.0     13654
# 20.0    12888
# 33.0    12755
# 12.0    10851
# 32.0     9729
# 11.0     9542
# 30.0     9214
# 34.0     6349
# 23.0     2427
# Name: TRANSIT_DISTRICT, dtype: int64

# %%
df.PD_DESC.value_counts()
# Out:
# FORGERY,ETC.,UNCLASSIFIED-FELO                                  11595
# ASSAULT 3                                                       10479
# LARCENY,PETIT FROM OPEN AREAS,                                   9485
# WEAPONS, POSSESSION, ETC                                         8632
# LARCENY,GRAND FROM PERSON,UNCL                                   6692
# RESISTING ARREST                                                 6297
# CRIMINAL MISCHIEF 4TH, GRAFFIT                                   5761
# SEXUAL ABUSE 3,2                                                 5354
# HARASSMENT,SUBD 1,CIVILIAN                                       4814
# TAMPERING 1,CRIMINAL                                             4711
# CONTROLLED SUBSTANCE, POSSESSI                                   4388
# UNAUTH. SALE OF TRANS. SERVICE                                   3965
# HARASSMENT,SUBD 3,4,5                                            3420
# ...

# %%
df.head()
# Out:
#      CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 16    487987088   05/19/2014     01:00:00   05/19/2014     06:55:00
# 97    446075066   05/16/2014     19:40:00          NaN          NaN
# 103   342454686   05/16/2014     17:50:00   05/16/2014     17:55:00
# 105   590259114   05/16/2014     17:00:00          NaN          NaN
# 437   817586413   05/19/2014     19:30:00   05/19/2014     19:40:00
#
#      ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 16          77.0  05/20/2014    121  CRIMINAL MISCHIEF & RELATED OF  268.0
# 97          13.0  05/20/2014    341                   PETIT LARCENY  339.0
# 103         40.0  05/20/2014    578                   HARRASSMENT 2  637.0
# 105         33.0  05/20/2014    341                   PETIT LARCENY  339.0
# 437         62.0  05/19/2014    351  CRIMINAL MISCHIEF & RELATED OF  258.0
#
#      ...   Latitude  Longitude                        Lat_Lon  \
# ...

# %%
df[df['CMPLNT_year']>=2006].groupby(['HADEVELOPT','CMPLNT_year']).size().unstack().sort_values(2018,ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-423eadfbde32> in <module>
# ----> 1 df[df['CMPLNT_year']>=2006].groupby(['HADEVELOPT','CMPLNT_year']).size().unstack().sort_values(2018,ascending=False)
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# ...

# %%
df[df['CMPLNT_year'] == 2018].HADEVELOPT
# Out:
# 1608099    NaN
# 1608132    NaN
# 1608163    NaN
# 1608166    NaN
# 1608171    NaN
# 1608197    NaN
# 1608253    NaN
# 1608386    NaN
# 1608408    NaN
# 1608468    NaN
# 1608476    NaN
# 1608520    NaN
# 1608567    NaN
# 1608679    NaN
# 1608680    NaN
# 1608760    NaN
# 1608875    NaN
# 1609152    NaN
# 1609157    NaN
# 1609170    NaN
# 1609211    NaN
# 1609235    NaN
# 1609268    NaN
# 1609414    NaN
# 1609526    NaN
# 1609632    NaN
# 1609635    NaN
# 1609681    NaN
# 1609697    NaN
# 1609749    NaN
#           ...
# 2070100    NaN
# 2070218    NaN
# 2070228    NaN
# 2070240    NaN
# 2070244    NaN
# 2070251    NaN
# 2070262    NaN
# 2070336    NaN
# 2070337    NaN
# 2070373    NaN
# 2070399    NaN
# 2070416    NaN
# 2070428    NaN
# 2070437    NaN
# 2070457    NaN
# 2070458    NaN
# 2070612    NaN
# 2070726    NaN
# 2070727    NaN
# 2070749    NaN
# 2071269    NaN
# 2071339    NaN
# 2071535    NaN
# 2071726    NaN
# 2071763    NaN
# 2071850    NaN
# 2071859    NaN
# ...

# %%
df
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 16        487987088   05/19/2014     01:00:00   05/19/2014     06:55:00
# 97        446075066   05/16/2014     19:40:00          NaN          NaN
# 103       342454686   05/16/2014     17:50:00   05/16/2014     17:55:00
# 105       590259114   05/16/2014     17:00:00          NaN          NaN
# 437       817586413   05/19/2014     19:30:00   05/19/2014     19:40:00
# 479       629219487   05/19/2014     18:50:00   05/19/2014     18:55:00
# 493       694092954   05/19/2014     18:35:00          NaN          NaN
# 527       112676906   05/19/2014     17:55:00   05/19/2014     18:20:00
# 590       933410541   05/19/2014     16:45:00          NaN          NaN
# 634       824195960   05/19/2014     15:50:00   05/19/2014     16:00:00
# 650       697535556   05/19/2014     15:30:00   05/19/2014     15:34:00
# 666       753257912   05/19/2014     15:25:00   05/19/2014     15:33:00
# ...
