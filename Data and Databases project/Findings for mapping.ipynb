# %%
import pandas as pd

# %%
df = pd.read_csv("1719-analysis by subject_adjusted.csv")

# %%
df.Subject.value_counts().head(10)
# Out:
# Moody's Investors Service Hong Kong Limited    4
# LEFT Andrew Edward                             3
# LEE Kwok Wa                                    3
# MUI Ka Leung Anson                             3
# AU-YEUNG Siu Pang                              3
# Zhongtai International Securities Limited      3
# CHAN Lit Chun                                  3
# Interactive Brokers Hong Kong Limited          3
# LEE Siu Ying Patsy                             3
# LAM Yik Tung                                   3
# Name: Subject, dtype: int64

# %%
df = df[df.Category != 'Court']
df = df[df.Category != 'Targetting clients']

# %%
df.Subject.value_counts().head(10)
# Out:
# Credit Suisse (Hong Kong) Limited                            2
# KEUNG Wai Fun Samantha                                       2
# Citigroup Global Markets Asia Limited                        2
# Merrill Lynch Far East Limited                               2
# Standard Chartered Securities (Hong Kong) Limited            2
# Credit Suisse AG                                             2
# KWOK Lai Kwan, Fonia                                         2
# China Merchants Securities (HK) Co., Limited                 2
# Interactive Brokers Hong Kong Limited                        2
# Health and Happiness (H&H) International Holdings Limited    2
# Name: Subject, dtype: int64

# %%
df.sort_values(by='Fine', ascending =False).head(20)
# Out:
#             Date                                            Subject  \
# 8    21 Nov 2017                      HSBC Private Bank (Suisse) SA
# 296  14 Mar 2019                   UBS Securities Hong Kong Limited
# 295  14 Mar 2019                                             UBS AG
# 292  14 Mar 2019                        Morgan Stanley Asia Limited
# 291  14 Mar 2019                     Merrill Lynch Far East Limited
# 293  14 Mar 2019  Standard Chartered Securities (Hong Kong) Limited
# 183  17 May 2018              Citigroup Global Markets Asia Limited
# 222   8 Feb 2018       Credit Suisse Securities (Hong Kong) Limited
# 221   8 Feb 2018                                   Credit Suisse AG
# 220   8 Feb 2018                  Credit Suisse (Hong Kong) Limited
# 267  27 May 2019       China Merchants Securities (HK) Co., Limited
# 176   9 Jul 2018                  CCB International Capital Limited
# 198  13 Apr 2018                           Instinet Pacific Limited
# ...

# %%
df[df.Subject.str.contains('HSBC')]
# Out:
#             Date                                 Subject  \
# 8    21 Nov 2017           HSBC Private Bank (Suisse) SA
# 172  19 Jul 2018  HSBC Broking Securities (Asia) Limited
#
#                                Organization  \
# 8             HSBC Private Bank (Suisse) SA
# 172  HSBC Broking Securities (Asia) Limited
#
#                                                 Action                URL  \
# 8    HSBC Private Bank (Suisse) SA fined HK$400 mil...  doc?refNo=17PR138
# 172  SFC reprimands and fines HSBC Broking Securiti...   doc?refNo=18PR86
#
#                                                Summary             Category  \
# 8    HSBC Private Bank (Suisse) SA, the Hong Kong b...    Systemic failures
# 172  The Securities and Futures Commission (SFC) ha...  Regulatory breaches
#
#             Fine  Penalty_Period  Jail_Term
# 8    400000000.0             NaN        NaN
# 172    9600000.0             NaN        NaN

# %%
df = df.dropna(subset=['Organization'])
df[df.Organization.str.contains('HSBC')]
# Out:
#             Date                                 Subject  \
# 8    21 Nov 2017           HSBC Private Bank (Suisse) SA
# 87   20 Mar 2017                  LEUNG Ming Yin, Philip
# 104  13 Feb 2017                              LI Lee Eva
# 159  20 Sep 2018                           NGO Wing Chun
# 172  19 Jul 2018  HSBC Broking Securities (Asia) Limited
#
#                                           Organization  \
# 8                        HSBC Private Bank (Suisse) SA
# 87              HSBC Broking Securities (Asia) Limited
# 104  The Hongkong and Shanghai Banking Corporation ...
# 159  Hongkong and Shanghai Banking Corporation Limi...
# 172             HSBC Broking Securities (Asia) Limited
#
#                                                 Action                URL  \
# 8    HSBC Private Bank (Suisse) SA fined HK$400 mil...  doc?refNo=17PR138
# 87       SFC bans Philip Leung Ming Yin for six months   doc?refNo=17PR37
# ...

# %%
df[df.Organization.str.contains('Hongkong')]
# Out:
#             Date        Subject  \
# 50   13 Jun 2017          LI Bo
# 104  13 Feb 2017     LI Lee Eva
# 159  20 Sep 2018  NGO Wing Chun
#
#                                           Organization  \
# 50   The Hongkong and Shanghai Banking Corporation ...
# 104  The Hongkong and Shanghai Banking Corporation ...
# 159  Hongkong and Shanghai Banking Corporation Limi...
#
#                                    Action                URL  \
# 50        SFC bans Li Bo for eight months   doc?refNo=17PR82
# 104              SFC bans Li Lee for life   doc?refNo=17PR20
# 159  SFC bans Ngo Wing Chun for 12 months  doc?refNo=18PR109
#
#                                                Summary              Category  \
# 50   The Securities and Futures Commission (SFC) ha...  Banned from industry
# 104  The Securities and Futures Commission (SFC) ha...  Banned from industry
# 159  The Securities and Futures Commission (SFC) ha...  Banned from industry
#
#      Fine  Penalty_Period  Jail_Term
# ...

# %%
df[df.Subject.str.contains('Citi')]
# Out:
#             Date                                Subject  \
# 175  10 Jul 2018  Citigroup Global Markets Asia Limited
# 183  17 May 2018  Citigroup Global Markets Asia Limited
#
#                               Organization  \
# 175  Citigroup Global Markets Asia Limited
# 183  Citigroup Global Markets Asia Limited
#
#                                                 Action               URL  \
# 175  SFC reprimands and fines Citigroup Global Mark...  doc?refNo=18PR78
# 183  SFC reprimands and fines Citigroup Global Mark...  doc?refNo=18PR51
#
#                                                Summary             Category  \
# 175  The Securities and Futures Commission (SFC) ha...  Regulatory breaches
# 183  The Securities and Futures Commission (SFC) ha...     Sponsor failures
#
#            Fine  Penalty_Period  Jail_Term
# 175   4000000.0             NaN        NaN
# 183  57000000.0             NaN        NaN

# %%
df[df.Organization.str.contains('UBS')]
# Out:
#             Date                           Subject  \
# 206  21 Mar 2018       UBS SECURITIES ASIA LIMITED
# 294  14 Mar 2019                          CEN Tian
# 295  14 Mar 2019                            UBS AG
# 296  14 Mar 2019  UBS Securities Hong Kong Limited
#
#                          Organization  \
# 206       UBS SECURITIES ASIA LIMITED
# 294                            UBS AG
# 295                            UBS AG
# 296  UBS Securities Hong Kong Limited
#
#                                                 Action               URL  \
# 206  SFC reprimands and fines UBS Securities Asia L...  doc?refNo=18PR30
# 294  SFC fines UBS $375 million and suspends its li...  doc?refNo=19PR19
# 295  SFC fines UBS $375 million and suspends its li...  doc?refNo=19PR19
# 296  SFC fines UBS $375 million and suspends its li...  doc?refNo=19PR19
#
#                                                Summary          Category  \
# ...

# %%
df[df.Organization.str.contains('Standard')]
# Out:
#             Date                                            Subject  \
# 2    18 Dec 2017  Standard Chartered Securities (Hong Kong) Limited
# 174  17 Jul 2018                               HSU Kar Hing, Joseph
# 293  14 Mar 2019  Standard Chartered Securities (Hong Kong) Limited
#
#                                           Organization  \
# 2    Standard Chartered Securities (Hong Kong) Limited
# 174  Standard Chartered Securities (Hong Kong) Limited
# 293  Standard Chartered Securities (Hong Kong) Limited
#
#                                                 Action                URL  \
# 2    SFC reprimands and fines Standard Chartered Se...  doc?refNo=17PR152
# 174       SFC bans Joseph Hsu Kar Hing for three years   doc?refNo=18PR85
# 293  SFC reprimands and fines Standard Chartered Se...   doc?refNo=19PR20
#
#                                                Summary  \
# 2    The Securities and Futures Commission (SFC) ha...
# ...

# %%
df[df.Organization.str.contains('Merchant')]
# Out:
#             Date                                       Subject  \
# 265  30 May 2019  China Merchants Securities (HK) Co., Limited
# 267  27 May 2019  China Merchants Securities (HK) Co., Limited
# 299  27 Feb 2019                                     WU Yinong
#
#                                      Organization  \
# 265  China Merchants Securities (HK) Co., Limited
# 267  China Merchants Securities (HK) Co., Limited
# 299  China Merchants Securities (HK) Co., Limited
#
#                                                 Action               URL  \
# 265  SFC reprimands and fines China Merchants Secur...  doc?refNo=19PR46
# 267  SFC reprimands and fines China Merchants Secur...  doc?refNo=19PR44
# 299  SFC suspends CMS’s former responsible officer ...  doc?refNo=19PR15
#
#                                                Summary  \
# 265  The Securities and Futures Commission (SFC) ha...
# 267  The Securities and Futures Commission (SFC) ha...
# ...

# %%
df[df.Penalty_Period > 1]['Organization'].value_counts().head(10)
# Out:
# Mayer Holdings Limited                           9
# Greencool Technology Holdings Limited            5
# Hanergy Thin Film Power Group Limited            5
# First Natural Foods Holdings Limited             3
# Citibank (Hong Kong) Limited                     3
# FT Securities Limited                            2
# Yorkey Optical International (Cayman) Limited    2
# Bank of China (Hong Kong) Limited                2
# Starlight Culture Entertainment Group Limited    1
# UBS Securities Hong Kong Limited                 1
# Name: Organization, dtype: int64

# %%
df[df.Jail_Term > 0]
# Out:
#             Date            Subject                     Organization  \
# 301  19 Feb 2019  AU-YEUNG Siu Pang  China CBM Group Company Limited
#
#                                                 Action               URL  \
# 301  Former GEM-listed group finance manager jailed...  doc?refNo=19PR11
#
#                                                Summary         Category  \
# 301  The Eastern Magistrates’ Court today sentenced...  Insider dealing
#
#          Fine  Penalty_Period  Jail_Term
# 301  120000.0             NaN        4.0
